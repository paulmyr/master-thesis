# %% [markdown]
# # Loss Landscape Visualization
#
# Sweeps all pairs of trainable AdEx parameters over a grid, simulates at each point,
# and plots the loss surfaces as:
# 1. A lower-triangle grid of 2D contour plots (21 pairs)
# 2. Individual 3D surface plots with contour projection (Ackley-style)

# %%
import copy
import logging
import time
from itertools import combinations

import jax
import jax.numpy as jnp
import jax.random as jr
import numpy as np
from jax import config

from ADoptEX.core import simulate_jaxley
from ADoptEX.core.data import TraceData, crop_to_stim_window, detect_spikes, load_trace
from ADoptEX.core.parameters import DEFAULT_PARAMS, NAUD_PARAMETERS, PARAM_BOUNDS
from ADoptEX.core.simulation import simulate_with_current_trace
from ADoptEX.evaluation.coincidence import coincidence_factor
from ADoptEX.loss import (
    GuarinoFeatures,
    GuarinoLossConfig,
    VanRossumLossConfig,
    extract_experimental_features,
    guarino_loss,
    make_guarino_loss_fn,
    make_van_rossum_loss_fn,
    spike_train_from_voltage,
)
from ADoptEX.plotting import (
    fit_before_after_plot,
    fit_comparison_plot,
    parameter_comparison_plot,
    spike_timing_plot,
    trace_plot,
    trace_stim_window_plot,
    training_comparison_plot,
    training_history_plot,
)
from ADoptEX.training import TrainingResult
from ADoptEX.training.trainer import TrainingConfig, setup_trainable_cell, train

config.update("jax_platform_name", "cpu")
logging.basicConfig(level=logging.INFO, format="%(message)s")

import matplotlib.pyplot as plt
from matplotlib import cm

# %% [markdown]
# ## 1. Load & Crop Data

# %%
initial_params = dict(NAUD_PARAMETERS["tonic"])
initial_params["v_threshold"] = 0.0
print(initial_params)

current_pA = initial_params["I"]

t_max_ms = 100
dt_ms = 0.025
T = np.linspace(0, t_max_ms, int(t_max_ms / dt_ms))

sim_init = simulate_jaxley(
    params=initial_params,
    stim_current_pA=current_pA,
    stim_duration_ms=100,
    dt_ms=dt_ms,
    t_max_ms=t_max_ms,
    stim_delay_ms=0.0,
    use_surrogate=False,
)

T = np.append(T, T[-1] + dt_ms)
print(len(T))
# Out:
# {'C_m': 200.0, 'g_L': 10.0, 'E_L': -70.0, 'v_T': -50.0, 'delta_T': 2.0, 'v_reset': -58.0, 'v_threshold': 0.0, 'tau_w': 30.0, 'a': 2.0, 'b': 0.0, 'I': 500.0}
# Added 1 recordings. See `.recordings` for details.
# Added 1 recordings. See `.recordings` for details.
# Added 1 recordings. See `.recordings` for details.
# Added 1 external_states. See `.externals` for details.
# /Users/paulmayer/Projects/university/40_thesis/3_jaxley/jaxley/channels/non_capacitive/adex.py:82: UserWarning: The AdEx channel does not support surrogate gradients. Its gradient will be zero after every spike. Use AdExSurrogate for differentiable spiking.
#   warn(
# 4001

# %% [markdown]
# ## 2. Setup Cell & Loss Function

# %%
from ADoptEX.loss import (
    extract_experimental_features,
    GuarinoLossConfig,
    make_guarino_loss_fn,
)

training_config = TrainingConfig(
    optimizer="adam",
    learning_rate=0.01,
    n_epochs=1,
    surrogate_type="sigmoid",
    surrogate_slope=5.0,
)

trace_stim_window_plot(TraceData(
    T,
    sim_init.voltage,
    np.full(len(T), initial_params["I"]),
    dt_ms,
    sim_init.spike_times,
    0,
    len(T),
    initial_params["I"]))

cell, data_stimuli, t_max, trainable_params = setup_trainable_cell(
    initial_params=initial_params,
    current_trace_pA=np.full(len(T), initial_params["I"]),
    dt_ms=dt_ms,
    config=training_config,
)

target_voltage = jnp.array(sim_init.voltage)
stim_end_index = t_max_ms  # already 0-based in cropped trace

# loss_name = 'MSE'
# loss_fn = make_mse_loss_fn(
#     cell=cell,
#     data_stimuli=data_stimuli,
#     t_max=t_max,
#     dt_ms=data.dt_ms,
#     exp_voltage=target_voltage,
#     stim_end_index=data.stim_end_idx,
#     loss_config=MSELossConfig(normalize=False, clamp_threshold=None),
# )


# Extract target features from experimental trace (hard spike detection)
exp_features = extract_experimental_features(
    voltage_trace=target_voltage,
    dt_ms=dt_ms,
    stim_duration_ms=stim_end_index,
    stim_end_index=len(sim_init.voltage),
    spike_threshold_mv=-35
)

loss_name = "Guarino"
loss_fn = make_guarino_loss_fn(
    cell=cell,
    data_stimuli=data_stimuli,
    t_max=t_max,
    dt_ms=dt_ms,
    exp_features=exp_features,
    stim_duration_ms=t_max_ms,
    stim_end_index=len(sim_init.voltage),
    loss_config=GuarinoLossConfig(
        weight_spike_count=0.0,
    ),
)


# Build param name -> index mapping
param_index = {}
for i, p in enumerate(trainable_params):
    for k in p:
        param_index[k.replace("AdEx_", "")] = i

PARAM_NAMES = list(param_index.keys())
N_PARAMS = len(PARAM_NAMES)

loss_init = loss_fn(trainable_params)
print(f"Initial loss: {float(loss_init):.4f}")
print(f"Trainable parameters ({N_PARAMS}): {PARAM_NAMES}")
print(f"Initial parameters: {initial_params}")
# Out:
# Added 1 recordings. See `.recordings` for details.
# Added 1 recordings. See `.recordings` for details.
# Added 1 recordings. See `.recordings` for details.
# Number of newly added trainable parameters: 1. Total number of trainable parameters: 1
# Number of newly added trainable parameters: 1. Total number of trainable parameters: 2
# Number of newly added trainable parameters: 1. Total number of trainable parameters: 3
# Number of newly added trainable parameters: 1. Total number of trainable parameters: 4
# Number of newly added trainable parameters: 1. Total number of trainable parameters: 5
# Number of newly added trainable parameters: 1. Total number of trainable parameters: 6
# Number of newly added trainable parameters: 1. Total number of trainable parameters: 7
# Number of newly added trainable parameters: 1. Total number of trainable parameters: 8
# Initial loss: 0.0084
# Trainable parameters (8): ['capacitance', 'g_L', 'E_L', 'v_T', 'v_reset', 'tau_w', 'a', 'b']
# Initial parameters: {'C_m': 200.0, 'g_L': 10.0, 'E_L': -70.0, 'v_T': -50.0, 'delta_T': 2.0, 'v_reset': -58.0, 'v_threshold': 0.0, 'tau_w': 30.0, 'a': 2.0, 'b': 0.0, 'I': 500.0}

# %% [markdown]
# ## 3. Sweep All Parameter Pairs
#
# For each of the C(7,2) = 21 pairs, build a grid over their PARAM_BOUNDS and
# evaluate the loss. Non-swept parameters stay at their default values.

# %%
GRID_SIZE = 20  # 20x20 per pair; 21 pairs * 400 = 8400 simulations

pairs = list(combinations(range(N_PARAMS), 2))
print(f"{len(pairs)} parameter pairs, {GRID_SIZE}x{GRID_SIZE} grid each")
print(f"Total simulations: {len(pairs) * GRID_SIZE**2}")
# Out:
# 28 parameter pairs, 20x20 grid each
# Total simulations: 11200

# %%
# Storage for all grids
grids = {}  # (i, j) -> {"X": ..., "Y": ..., "Z": ...}

t_start = time.time()

for pair_idx, (pi, pj) in enumerate(pairs):
    px, py = PARAM_NAMES[pi], PARAM_NAMES[pj]
    bx, by = PARAM_BOUNDS[px], PARAM_BOUNDS[py]

    x_vals = np.linspace(bx.min, bx.max, GRID_SIZE)
    y_vals = np.linspace(by.min, by.max, GRID_SIZE)
    X, Y = np.meshgrid(x_vals, y_vals)
    Z = np.full((GRID_SIZE, GRID_SIZE), np.nan)

    ix, iy = param_index[px], param_index[py]

    pxrc = f"AdEx_{px}" if px != "capacitance" else px
    pyrc = f"AdEx_{py}" if py != "capacitance" else py
    for r in range(GRID_SIZE):
        for c in range(GRID_SIZE):
            params_rc = copy.deepcopy(trainable_params)
            params_rc[ix] = {pxrc: jnp.array([X[r, c]])}
            params_rc[iy] = {pyrc: jnp.array([Y[r, c]])}
            try:
                Z[r, c] = float(loss_fn(params_rc))
            except Exception:
                Z[r, c] = np.nan

    grids[(pi, pj)] = {"X": X, "Y": Y, "Z": Z}

    elapsed = time.time() - t_start
    eta = elapsed / (pair_idx + 1) * (len(pairs) - pair_idx - 1)
    print(
        f"  [{pair_idx+1:2d}/{len(pairs)}] {px:>8s} vs {py:<8s}  "
        f"loss=[{np.nanmin(Z):.1f}, {np.nanmax(Z):.1f}]  "
        f"elapsed={elapsed:.0f}s  ETA={eta:.0f}s"
    )

print(f"\nTotal time: {time.time() - t_start:.0f}s")
# Out:
#   [ 1/28] capacitance vs g_L       loss=[0.0, 1.9]  elapsed=69s  ETA=1857s
#   [ 2/28] capacitance vs E_L       loss=[0.0, 60246.7]  elapsed=133s  ETA=1725s
#   [ 3/28] capacitance vs v_T       loss=[0.1, 11.7]  elapsed=197s  ETA=1641s
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[17], line 25
#      23 params_rc[iy] = {pyrc: jnp.array([Y[r, c]])}
#      24 try:
# ---> 25     Z[r, c] = float(loss_fn(params_rc))
#      26 except Exception:
#      27     Z[r, c] = np.nan
#
# File ~/Projects/university/40_thesis/5_code/ADoptEX/loss/guarino.py:803, in make_guarino_loss_fn.<locals>.loss_fn(params)
#     801 def loss_fn(params):
#     802     # Run simulation with current parameters
# --> 803     results = jx.integrate(
#     804         cell, params=params, data_stimuli=data_stimuli, delta_t=dt_ms, t_max=t_max
#     805     )
#     807     # Extract traces
#     808     # results[0] = voltage, results[1] = w, results[2] = spikes
#     809     voltage = results[0].flatten()
#
# File ~/Projects/university/40_thesis/3_jaxley/jaxley/integrate.py:458, in integrate(module, params, param_state, data_stimuli, data_clamps, t_max, delta_t, solver, voltage_solver, checkpoint_lengths, all_states, return_states)
#     455 init_recording = jnp.expand_dims(init_recs, axis=0)
#     457 # Run simulation.
# --> 458 all_states, recordings = nested_checkpoint_scan(
#     459     _body_fun,
#     460     all_states,
#     461     externals,
#     462     length=length,
#     463     nested_lengths=checkpoint_lengths,
#     464 )
#     465 recs = jnp.concatenate([init_recording, recordings[:nsteps_to_return]], axis=0).T
#     466 return (recs, all_states) if return_states else recs
#
# File ~/Projects/university/40_thesis/3_jaxley/jaxley/utils/jax_utils.py:61, in nested_checkpoint_scan(f, init, xs, length, nested_lengths, scan_fn, checkpoint_fn)
#      58     return x.reshape(new_shape)
#      60 sub_xs = jax.tree_util.tree_map(nested_reshape, xs)
# ---> 61 return _inner_nested_scan(f, init, sub_xs, nested_lengths, scan_fn, checkpoint_fn)
#
# File ~/Projects/university/40_thesis/3_jaxley/jaxley/utils/jax_utils.py:67, in _inner_nested_scan(f, init, xs, lengths, scan_fn, checkpoint_fn)
#      65 """Recursively applied scan function."""
#      66 if len(lengths) == 1:
# ---> 67     return scan_fn(f, init, xs, lengths[0])
#      69 @checkpoint_fn
#      70 def sub_scans(carry, xs):
#      71     return _inner_nested_scan(f, carry, xs, lengths[1:], scan_fn, checkpoint_fn)
#
#     [... skipping hidden 1 frame]
#
# File ~/Projects/university/40_thesis/.venv/lib/python3.14/site-packages/jax/_src/lax/control_flow/loops.py:251, in scan(f, init, xs, length, reverse, unroll, _split_transpose)
#     241   return jaxpr, out_avals, consts
#     243 # The carry input and output avals must match exactly. However, we want to account for
#     244 # the case when init contains weakly-typed values (e.g. Python scalars), with avals that
#     245 # may not match the output despite being compatible by virtue of their weak type.
#    (...)    249 # depth) and incomplete (because in the general case it takes more than two passes).
#     250 # Let's get rid of it, perhaps after getting rid of weak types altogether.
# --> 251 jaxpr, out_avals, consts = _create_jaxpr(init_avals)
#     252 if config.mutable_array_checks.value:
#     253   _check_no_aliased_closed_over_refs(dbg_body, consts, list(args))
#
# File ~/Projects/university/40_thesis/.venv/lib/python3.14/site-packages/jax/_src/lax/control_flow/loops.py:236, in scan.<locals>._create_jaxpr(carry_avals)
#     234 def _create_jaxpr(carry_avals):
#     235   new_arg_avals = FlatTree.pack(((carry_avals, x_avals), {}))
# --> 236   jaxpr, out_avals = pe.trace_to_jaxpr(f, new_arg_avals, dbg_body)
#     237   jaxpr, consts = pe.separate_consts(jaxpr)
#     238   if len(out_avals.unpack()) != 2:
#
# File ~/Projects/university/40_thesis/.venv/lib/python3.14/site-packages/jax/_src/interpreters/partial_eval.py:2412, in trace_to_jaxpr(***failed resolving arguments***)
#    2410 with core.set_current_trace(trace):
#    2411   args, kwargs = in_tracers.unflatten()
# -> 2412   ans_pytree = fun(*args, **kwargs)
#    2413   debug_info = debug_info.set_result_paths(ans_pytree)
#    2414   ans = FlatTree.flatten(ans_pytree)
#
# File ~/Projects/university/40_thesis/3_jaxley/jaxley/integrate.py:414, in integrate.<locals>._body_fun(state, externals)
#     413 def _body_fun(state, externals):
# --> 414     state = step_fn(state, all_params, externals, external_inds, delta_t)
#     415     recs = jnp.asarray(
#     416         [
#     417             state[rec_state][rec_ind]
#     418             for rec_state, rec_ind in zip(rec_states, rec_inds)
#     419         ]
#     420     )
#     421     return state, recs
#
# File ~/Projects/university/40_thesis/3_jaxley/jaxley/integrate.py:188, in build_init_and_step_fn.<locals>.step_fn(all_states, all_params, externals, external_inds, delta_t)
#     175 """Performs a single integration step with step size delta_t.
#     176
#     177 Args:
#    (...)    185     Updated states.
#     186 """
#     187 state = all_states
# --> 188 state = module.step(
#     189     state,
#     190     delta_t,
#     191     external_inds,
#     192     externals,
#     193     params=all_params,
#     194     solver=solver,
#     195     voltage_solver=voltage_solver,
#     196 )
#     197 return state
#
# File ~/Projects/university/40_thesis/3_jaxley/jaxley/modules/base.py:78, in only_allow_module.<locals>.wrapper(self, *args, **kwargs)
#      73 method_name = func.__name__
#      74 assert not isinstance(self, View), (
#      75     f"{method_name} is currently not supported for Views. Call on "
#      76     f"the {module_name} base Module."
#      77 )
# ---> 78 return func(self, *args, **kwargs)
#
# File ~/Projects/university/40_thesis/3_jaxley/jaxley/modules/base.py:2857, in Module.step(self, u, delta_t, external_inds, externals, params, solver, voltage_solver)
#    2853     i_ext = 0.0
#    2855 # Steps of the channel & pump states and computes the current through these
#    2856 # channels and pumps.
# -> 2857 u, (linear_terms, const_terms) = self._step_channels(
#    2858     u, delta_t, self.channels + self.pumps, self.nodes, params
#    2859 )
#    2861 # Step of the synapse.
#    2862 u, (v_syn_linear_terms, v_syn_const_terms) = self._step_synapse(
#    2863     u,
#    2864     self.synapses,
#    (...)   2867     self.edges,
#    2868 )
#
# File ~/Projects/university/40_thesis/3_jaxley/jaxley/modules/base.py:3091, in Module._step_channels(self, states, delta_t, channels, channel_nodes, params)
#    3082 def _step_channels(
#    3083     self,
#    3084     states: dict[str, Array],
#    (...)   3088     params: dict[str, Array],
#    3089 ) -> tuple[dict[str, Array], tuple[Array, Array]]:
#    3090     """One step of integration of the channels and of computing their current."""
# -> 3091     states = self._step_channels_state(
#    3092         states, delta_t, channels, channel_nodes, params
#    3093     )
#    3094     states, current_terms = self._channel_currents(
#    3095         states, delta_t, channels, channel_nodes, params
#    3096     )
#    3097     return states, current_terms
#
# File ~/Projects/university/40_thesis/3_jaxley/jaxley/modules/base.py:3132, in Module._step_channels_state(self, states, delta_t, channels, channel_nodes, params)
#    3124 channel_params = query_channel_states_and_params(
#    3125     params, channel_param_names, channel_indices
#    3126 )
#    3127 channel_states = query_channel_states_and_params(
#    3128     states, channel_state_names, channel_indices
#    3129 )
#    3131 states_updated = channel.update_states(
# -> 3132     channel_states, delta_t, voltages[channel_indices], channel_params
#    3133 )
#    3134 # Rebuild state. This has to be done within the loop over channels to allow
#    3135 # multiple channels which modify the same state.
#    3136 for key, val in states_updated.items():
#
# File ~/Projects/university/40_thesis/.venv/lib/python3.14/site-packages/jax/_src/numpy/array_methods.py:1146, in _forward_operator_to_aval.<locals>.op(self, *args)
#    1145 def op(self, *args):
# -> 1146   return getattr(self.aval, f"_{name}")(self, *args)
#
# File ~/Projects/university/40_thesis/.venv/lib/python3.14/site-packages/jax/_src/numpy/array_methods.py:683, in _getitem(self, item)
#     682 def _getitem(self, item):
# --> 683   return indexing.rewriting_take(self, item)
#
# File ~/Projects/university/40_thesis/.venv/lib/python3.14/site-packages/jax/_src/numpy/indexing.py:1208, in rewriting_take(arr, idx, indices_are_sorted, unique_indices, mode, fill_value, normalize_indices, out_sharding, strategy)
#    1204 # For simplicity of generated primitives, we call lax.slice or lax.dynamic_slice
#    1205 # in the simplest cases: i.e. non-dynamic arrays indexed with integers and slices.
#    1206 # TODO(jakevdp): lower to slice even when normalize_indices is False
#    1207 if strategy == IndexingStrategy.AUTO and normalize_indices:
# -> 1208   result = _attempt_rewriting_take_via_slice(arr, indexer, mode=mode, out_sharding=out_sharding)
#    1209   if result is not None:
#    1210     return result
#
# File ~/Projects/university/40_thesis/.venv/lib/python3.14/site-packages/jax/_src/numpy/indexing.py:1089, in _attempt_rewriting_take_via_slice(arr, indexer, mode, out_sharding)
#    1085   return None
#    1087 simple_revs = {i for i, ind in enumerate(idx) if _is_simple_reverse_slice(ind)}
#    1088 int_indices = {i for i, (ind, size) in enumerate(zip(idx, arr.shape))
# -> 1089                if _is_valid_integer_index_for_slice(ind, size, mode)}
#    1090 contiguous_slices = {i for i, ind in enumerate(idx) if _is_contiguous_slice(ind)}
#    1092 # For sharded inputs, indexing (like x[0]) and partial slices (like x[:2] as
#    1093 # opposed to x[:]) lead to incorrect sharding semantics when computed via
#    1094 # dynamic_slice, so we fall back to gather.
#    1095 # TODO(yashkatariya): fix dynamic_slice with sharding
#
# File ~/Projects/university/40_thesis/.venv/lib/python3.14/site-packages/jax/_src/numpy/indexing.py:1040, in _is_valid_integer_index_for_slice(idx, size, mode)
#    1035 def _is_simple_reverse_slice(idx: Any) -> bool:
#    1036   return (isinstance(idx, slice) and
#    1037           idx.start is idx.stop is None and
#    1038           isinstance(idx.step, int) and idx.step == -1)
# -> 1040 def _is_valid_integer_index_for_slice(idx, size, mode):
#    1041   if size == 0:
#    1042     return False
#
# KeyboardInterrupt:

# %% [markdown]
# ## 4. Triangle Grid — All Pairs (2D Contour)
#
# Lower-triangle matrix: row = second parameter, column = first parameter.
# Each cell shows a filled contour of the loss landscape for that pair.

# %%
fig, axes = plt.subplots(
    N_PARAMS,
    N_PARAMS,
    figsize=(3 * N_PARAMS, 3 * N_PARAMS),
    squeeze=False,
)

# Hide all axes first
for ax_row in axes:
    for ax in ax_row:
        ax.set_visible(False)

# Fill lower triangle
for (pi, pj), g in grids.items():
    ax = axes[pj, pi]  # row=pj (y-axis param), col=pi (x-axis param)
    ax.set_visible(True)

    Z_plot = np.clip(g["Z"], np.nanmin(g["Z"]), np.nanpercentile(g["Z"], 95))
    ax.contourf(g["X"], g["Y"], Z_plot, levels=20, cmap=cm.jet)
    ax.contour(
        g["X"], g["Y"], Z_plot, levels=8, colors="white", linewidths=0.3, alpha=0.5
    )

    def map_name_to_trainable_params(s):
        if s == "capacitance":
            return "C_m"
        return s
    # Mark default params
    ax.plot(
        initial_params[map_name_to_trainable_params(PARAM_NAMES[pi])],
        initial_params[map_name_to_trainable_params(PARAM_NAMES[pj])],
        "k+",
        markersize=8,
        markeredgewidth=2,
    )

    # Labels on edges only
    if pj == N_PARAMS - 1:  # bottom row
        ax.set_xlabel(PARAM_NAMES[pi], fontsize=10)
    else:
        ax.set_xticklabels([])
    if pi == 0:  # left column
        ax.set_ylabel(PARAM_NAMES[pj], fontsize=10)
    else:
        ax.set_yticklabels([])

    ax.tick_params(labelsize=7)

# Diagonal labels
for i in range(N_PARAMS):
    ax = axes[i, i]
    ax.set_visible(True)
    ax.text(
        0.5,
        0.5,
        PARAM_NAMES[i],
        transform=ax.transAxes,
        ha="center",
        va="center",
        fontsize=14,
        fontweight="bold",
    )
    ax.set_xticks([])
    ax.set_yticks([])
    for spine in ax.spines.values():
        spine.set_visible(False)

fig.suptitle(f"{loss_name} Loss Landscape — All Parameter Pairs", fontsize=18, y=1.01)
plt.tight_layout()
#plt.savefig(
#    f"{loss_name.lower()}_loss_landscape_grid.png", dpi=150, bbox_inches="tight"
#)
plt.show()
print(f"Saved to {loss_name.lower()}_loss_landscape_grid.png")
# Out:
# Saved to guarino_loss_landscape_grid.png

# %% [markdown]
# ## 5. Individual 3D Surface Plots
#
# Ackley-style 3D surface with contour projection for each parameter pair.

# %%
ax = plt.subplot(projection="3d")

surf = ax.plot_surface(
    X,
    Y,
    Z_plot,
    cmap=cm.jet,
    edgecolor="none",
    alpha=0.9,
    rstride=1,
    cstride=1,
)

# Contour projection on the floor
z_floor = ax.get_zlim()[0]
ax.contour(
    X,
    Y,
    Z_plot,
    levels=10,
    zdir="z",
    offset=z_floor,
    cmap=cm.jet,
    alpha=0.6,
)

ax.set_xlabel(px, fontsize=8, labelpad=2)
ax.set_ylabel(py, fontsize=8, labelpad=2)
ax.set_zlabel("Loss", fontsize=8, labelpad=2)
ax.set_title(f"{px} vs {py}", fontsize=10, pad=2)
ax.tick_params(labelsize=6)
ax.view_init(elev=30, azim=-60)

plt.tight_layout()
plt.savefig(
    f"{loss_name.lower()}_loss_landscape_3d_focus.pdf", dpi=150, bbox_inches="tight"
)
plt.show()
print(f"Saved to {loss_name.lower()}_loss_landscape_3d_focus.png")
# Out:
# Saved to guarino_loss_landscape_3d_focus.png
